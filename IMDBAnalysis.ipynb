# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapnilkk7753/IMDB_Analysis/blob/main/IMDBAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns

# %%
data = pd.read_csv('/content/IMDB-Movie-Data.csv')

# %% [markdown]
# # 1. Display Top 10 Rows of The Dataset

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
data.tail()
# Out:
#      Rank                     Title                    Genre  \
# 993   994  Resident Evil: Afterlife  Action,Adventure,Horror
# 994   995                 Project X                   Comedy
# 996   997           Hostel: Part II                   Horror
# 997   998    Step Up 2: The Streets      Drama,Music,Romance
# 999  1000                Nine Lives    Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 993  While still out to destroy the evil Umbrella C...  Paul W.S. Anderson
# 994  3 high school seniors throw a birthday party t...     Nima Nourizadeh
# 996  Three American college students studying abroa...            Eli Roth
# 997  Romantic sparks occur between two dance studen...          Jon M. Chu
# 999  A stuffy businessman finds himself trapped ins...    Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 993  Milla Jovovich, Ali Larter, Wentworth Miller,K...  2010
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (1000, 12)

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 1000
# Number of Columns 12

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# # 5. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # 6. Drop All The Missing Values

# %%
data.dropna(inplace=True, axis=0)

# %% [markdown]
# # 7. Check For Duplicate Data

# %%
dup_data=data.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %% [markdown]
# # 8. Get Overall Statistics About The DataFrame

# %%
-data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# # 9. Display Title of The Movie Having Runtime >= 180 Minutes

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %% [markdown]
# # 10. In Which Year There Was The Highest Voting?

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()

# %% [markdown]
# # 11. In Which Year There Was The Highest Revenue?

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# # 12. Find The Average Rating For Each Director

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Makoto Shinkai                      8.60
# Olivier Nakache                     8.60
# Aamir Khan                          8.50
# Florian Henckel von Donnersmarck    8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %% [markdown]
# # 13. Display Top 10 Lengthy Movies Title

# %%
le =data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]

# %%
le
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %%
sns.barplot(x=le['Runtime (Minutes)'],y=le.index)
plt.title('Top 5 Lengtly Movies')
plt.show()

# %% [markdown]
# # Display top 10 comedy movie on rating

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
cd=[]
l=0
for i in data.index:
  c=data.loc[i,'Genre']
  k=0
  for j in range(30):
   if c[k:j+6]=='Comedy':
    cd.append([data.loc[i,'Title'],data.loc[i,'Rating'],data.loc[i,'Revenue (Millions)'],data.loc[i,'Director']])
    l+=1
    break
   k+=1

# %%
comdata=pd.DataFrame(cd,columns=['Title','Rating','Revenue','Director'])

# %%
co=comdata.nlargest(10,'Rating')[['Title','Rating','Revenue']]
co
# Out:
#                         Title  Rating  Revenue
# 53           The Intouchables     8.6    13.18
# 102                  3 Idiots     8.4     6.52
# 1                  La La Land     8.3   151.06
# 119                        Up     8.3   292.98
# 168               Toy Story 3     8.3   414.98
# 16    The Wolf of Wall Street     8.2   116.87
# 49                 Inside Out     8.2   356.45
# 189                        PK     8.2    10.57
# 13                   Zootopia     8.1   341.26
# 48   The Grand Budapest Hotel     8.1    59.07

# %% [markdown]
# # Top 10 comedy movies on the basis of highest Ravenue in million doller

# %%
coo=comdata.nlargest(10,'Revenue')[['Title','Rating','Revenue']]
coo
# Out:
#                        Title  Rating  Revenue
# 22              Finding Dory     7.4   486.29
# 168              Toy Story 3     8.3   414.98
# 35                    Frozen     7.5   400.74
# 4    The Secret Life of Pets     6.6   368.31
# 198          Despicable Me 2     7.4   368.05
# 8                   Deadpool     8.0   363.02
# 49                Inside Out     8.2   356.45
# 13                  Zootopia     8.1   341.26
# 119                       Up     8.3   292.98
# 55              The Hangover     7.8   277.31

# %% [markdown]
# # Top 10 director which direct comedy movie on rating

# %%
co=comdata.nlargest(10,'Rating')[['Title','Director']]
co
# Out:
#                         Title         Director
# 53           The Intouchables  Olivier Nakache
# 102                  3 Idiots  Rajkumar Hirani
# 1                  La La Land  Damien Chazelle
# 119                        Up      Pete Docter
# 168               Toy Story 3      Lee Unkrich
# 16    The Wolf of Wall Street  Martin Scorsese
# 49                 Inside Out      Pete Docter
# 189                        PK  Rajkumar Hirani
# 13                   Zootopia     Byron Howard
# 48   The Grand Budapest Hotel     Wes Anderson

# %% [markdown]
# # Top 10 movies on the basis of Action

# %%
ac=[]
l=0
for i in data.index:
  c=data.loc[i,'Genre']
  k=0
  for j in range(30):
   if c[k:j+6]=='Action':
    ac.append([data.loc[i,'Title'],data.loc[i,'Rating'],data.loc[i,'Revenue (Millions)'],data.loc[i,'Director']])
    l+=1
    break
   k+=1

# %%
actdata=pd.DataFrame(ac,columns=['Title','Rating','Revenue','Director'])

# %% [markdown]
# # Top 10 action movies on the Rating

# %%
acc=actdata.nlargest(10,'Rating')[['Title','Rating']]
acc
# Out:
#                                           Title  Rating
# 20                              The Dark Knight     9.0
# 30                                    Inception     8.8
# 43                        The Dark Knight Rises     8.5
# 65                                      Warrior     8.2
# 0                       Guardians of the Galaxy     8.1
# 17   Star Wars: Episode VII - The Force Awakens     8.1
# 23                           Mad Max: Fury Road     8.1
# 27                                 The Avengers     8.1
# 117                                        Rush     8.1
# 151                        The Bourne Ultimatum     8.1

# %% [markdown]
# # Top 10 director which direct Action movie on rating

# %%
acc=actdata.nlargest(10,'Rating')[['Title','Director','Rating']]
acc
# Out:
#                                           Title           Director  Rating
# 20                              The Dark Knight  Christopher Nolan     9.0
# 30                                    Inception  Christopher Nolan     8.8
# 43                        The Dark Knight Rises  Christopher Nolan     8.5
# 65                                      Warrior     Gavin O'Connor     8.2
# 0                       Guardians of the Galaxy         James Gunn     8.1
# 17   Star Wars: Episode VII - The Force Awakens        J.J. Abrams     8.1
# 23                           Mad Max: Fury Road      George Miller     8.1
# 27                                 The Avengers        Joss Whedon     8.1
# 117                                        Rush         Ron Howard     8.1
# 151                        The Bourne Ultimatum    Paul Greengrass     8.1

# %% [markdown]
# # Top 10 Action movies on the basis of highest Ravenue in Million doller

# %%
acc=actdata.nlargest(10,'Revenue')[['Title','Revenue']]
acc
# Out:
#                                           Title  Revenue
# 17   Star Wars: Episode VII - The Force Awakens   936.63
# 33                                       Avatar   760.51
# 32                               Jurassic World   652.18
# 27                                 The Avengers   623.28
# 20                              The Dark Knight   533.32
# 4                                     Rogue One   532.17
# 36                      Avengers: Age of Ultron   458.99
# 43                        The Dark Knight Rises   448.13
# 192             The Hunger Games: Catching Fire   424.65
# 28   Pirates of the Caribbean: Dead Man's Chest   423.03

# %% [markdown]
# # Top 10 Horror movies

# %%
hr=[]
l=0
for i in data.index:
  c=data.loc[i,'Genre']
  k=0
  for j in range(30):
   if c[k:j+6]=='Horror':
    hr.append([data.loc[i,'Title'],data.loc[i,'Rating'],data.loc[i,'Revenue (Millions)'],data.loc[i,'Director']])
    l+=1
    break
   k+=1

# %%
hordata=pd.DataFrame(hr,columns=['Title','Rating','Revenue','Director'])

# %% [markdown]
# # Top 10 Horror movies on the Rating

# %%
hrr=hordata.nlargest(10,'Rating')[['Title','Rating']]
hrr
# Out:
#                                              Title  Rating
# 28                                      Zombieland     7.7
# 29                       What We Do in the Shadows     7.6
# 14                                        Raw (II)     7.5
# 17                                   The Conjuring     7.5
# 20                                      Busanhaeng     7.5
# 75                                         Goksung     7.5
# 9                                  The Conjuring 2     7.4
# 51  Sweeney Todd: The Demon Barber of Fleet Street     7.4
# 0                                            Split     7.3
# 2                                    Don't Breathe     7.2

# %% [markdown]
# # Top 10 director which direct horror movies on th rating

# %%
hrr=hordata.nlargest(10,'Rating')[['Title','Director','Rating']]
hrr
# Out:
#                                              Title            Director  Rating
# 28                                      Zombieland     Ruben Fleischer     7.7
# 29                       What We Do in the Shadows     Jemaine Clement     7.6
# 14                                        Raw (II)     Julia Ducournau     7.5
# 17                                   The Conjuring           James Wan     7.5
# 20                                      Busanhaeng        Sang-ho Yeon     7.5
# 75                                         Goksung         Hong-jin Na     7.5
# 9                                  The Conjuring 2           James Wan     7.4
# 51  Sweeney Todd: The Demon Barber of Fleet Street          Tim Burton     7.4
# 0                                            Split  M. Night Shyamalan     7.3
# 2                                    Don't Breathe        Fede Alvarez     7.2

# %% [markdown]
# # Top 10 Horror movies on the basis Revenue in millionj doller

# %%
hrr=hordata.nlargest(10,'Revenue')[['Title','Revenue']]
hrr
# Out:
#               Title  Revenue
# 39      I Am Legend   256.39
# 32      World War Z   202.35
# 0             Split   138.12
# 17    The Conjuring   137.39
# 9   The Conjuring 2   102.46
# 2     Don't Breathe    89.21
# 67        Annabelle    84.26
# 37      Cloverfield    80.03
# 58     Dark Shadows    79.71
# 28       Zombieland    75.59

# %% [markdown]
# # 14. Display Number of Movies Per Year

# %%
sns.countplot(x='Year',data=data)
plt.title("Number of Movies Per Year")
# Out:
# Text(0.5, 1.0, 'Number of Movies Per Year')

# %% [markdown]
# # 15. Find Most Popular Movie Title (Higest Revenue)

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# # 16. Display Top 10 Highest Rated Movie Titles And its Directors

# %%
top_10=data.nlargest(10,'Rating')[['Title','Rating','Director']]

# %%
top_10
# Out:
#                      Title  Rating                          Director
# 54         The Dark Knight     9.0                 Christopher Nolan
# 80               Inception     8.8                 Christopher Nolan
# 36            Interstellar     8.6                 Christopher Nolan
# 96           Kimi no na wa     8.6                    Makoto Shinkai
# 249       The Intouchables     8.6                   Olivier Nakache
# 64            The Prestige     8.5                 Christopher Nolan
# 99            The Departed     8.5                   Martin Scorsese
# 124  The Dark Knight Rises     8.5                 Christopher Nolan
# 133               Whiplash     8.5                   Damien Chazelle
# 476    The Lives of Others     8.5  Florian Henckel von Donnersmarck

# %%
sns.barplot(x=top_10['Rating'],top_10.index)
plt.title("Display Top 10 Highest Rated Movie Titles")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1471653688.py in <cell line: 0>()
# ----> 1 sns.barplot(top_10['Rating'],top_10.index)
#       2 plt.title("Display Top 10 Highest Rated Movie Titles")
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# # 17. Display Top 10 Highest Revenue Movie Titles

# %%
data.columns

# %%
data.sort_values(by='Revenue (Millions)',ascending=False).head(10)

# %%
top_10 = data.nlargest(10,'Revenue (Millions)')[['Title','Director','Revenue (Millions)']].set_index('Title')

# %%
sns.barplot(top_10['Revenue (Millions)'],top_10.index)
plt.title("Display Top 10 Highest Revenue Movie Titles")
plt.show()

# %% [markdown]
# # 18.  Find Average Rating of Movies Year-wise

# %%
data.columns

# %%
data1=data.groupby('Year')['Year','Rating'].mean().\
sort_values(by='Rating',ascending=False).set_index('Year')

# %%
data1

# %%
plt.figure(figsize=(10,5))
sns.barplot(data1.index,data1['Rating'])
plt.show()

# %% [markdown]
# # 19. Does Rating Affect The Revenue?

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# # Answer : Yes

# %% [markdown]
# # 20. Classify Movies Based on Ratings [Good,Better and Best]

# %%
data.columns

# %%
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore rating_cat
# 0     8.1  757074              333.13       76.0  Excellent

# %% [markdown]
# # 21. Count Number of Action Movies

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))

# %%
data['temp']=list1

# %%
genre=input("Enter Genre you want to count : ").title()
count=0
for value in data['temp']:
    if genre in value:
        count=count+1
print("Total Count is",count)
# Out:
# Enter Genre you want to count : Comedy
# Total Count is 250

# %% [markdown]
# # OR

# %%
len(data[data['Genre'].str.contains('action',case=False)])
# Out:
# 277
